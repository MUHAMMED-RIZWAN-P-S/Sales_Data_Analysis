# %% [markdown]
# ## Sales Data Analysis
# ABC Private Limited, a retail company, wants to gain insight into its customers' purchasing habits, particularly their spending on different product categories. To do this, they have provided a summary of the purchase history of a number of high-volume products from the previous month. This data includes information on the customer demographics, such as age, gender, marital status, city type, and length of stay in their current city, as well as details on the products themselves, including product ID and product category.

# %% [markdown]
# #### Data preprocessing and data visualization.

# %%
# Essential libraries for manipulations, calculations and visulaizations
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
# Importing and reading the data from the provided data files in csv format
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# Dropping the column Stay_In_Current_City_Years as it is irrelevent to the assigned task.
train = train.drop(['Stay_In_Current_City_Years'], axis=1)
train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 7.0
# ...

# %%
test = test.drop(['Stay_In_Current_City_Years'], axis=1)
test
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    1                   1                11.0
# ...

# %%
# Changing name of a column.
train = train.rename(columns = {'City_Category':'City'})
train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City  Marital_Status  \
# 0       1000001  P00069042      F   0-17          10    A               0
# 1       1000001  P00248942      F   0-17          10    A               0
# 2       1000001  P00087842      F   0-17          10    A               0
# 3       1000001  P00085442      F   0-17          10    A               0
# 4       1000002  P00285442      M    55+          16    C               0
# ...         ...        ...    ...    ...         ...  ...             ...
# 550063  1006033  P00372445      M  51-55          13    B               1
# 550064  1006035  P00375436      F  26-35           1    C               0
# 550065  1006036  P00375436      F  26-35          15    B               1
# 550066  1006038  P00375436      F    55+           1    C               0
# 550067  1006039  P00371644      F  46-50           0    B               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# ...

# %%
# All the columns are retuned as a list of the dataset attributes. It is particularly helpful when the datset contains 
# a large number of columns/attributes.
train.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City',
#        'Marital_Status', 'Product_Category_1', 'Product_Category_2',
#        'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# Extremely useful insight about the structure of the data, data types of each attribute and memory consumed.
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   User_ID             550068 non-null  int64
#  1   Product_ID          550068 non-null  object
#  2   Gender              550068 non-null  object
#  3   Age                 550068 non-null  object
#  4   Occupation          550068 non-null  int64
#  5   City                550068 non-null  object
#  6   Marital_Status      550068 non-null  int64
#  7   Product_Category_1  550068 non-null  int64
#  8   Product_Category_2  376431 non-null  float64
#  9   Product_Category_3  166822 non-null  float64
#  10  Purchase            550068 non-null  int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 46.2+ MB

# %%
# nother extremely important function which provides with mathematical insights of the data that gives as a good
# mathematical idea of the data.
train.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376431.000000       166822.000000  550068.000000
# mean             9.842322           12.668233    9263.968713
# std              5.086585            4.125327    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
# Shape of the data in the form of a tuple (Rows, Columns)
train.shape
# Out:
# (550068, 11)

# %%
# isnull() is used to find out the number of null values present in each entry. It returns boolean values for each entry 
# in the dataset as shown below.
train.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation   City  Marital_Status  \
# 0         False       False   False  False       False  False           False
# 1         False       False   False  False       False  False           False
# 2         False       False   False  False       False  False           False
# 3         False       False   False  False       False  False           False
# 4         False       False   False  False       False  False           False
# ...         ...         ...     ...    ...         ...    ...             ...
# 550063    False       False   False  False       False  False           False
# 550064    False       False   False  False       False  False           False
# 550065    False       False   False  False       False  False           False
# 550066    False       False   False  False       False  False           False
# 550067    False       False   False  False       False  False           False
#
# ...

# %%
# We use sum() function to get more understandable data about the null values. This functions gives the sum of all 
# null values for each column.
# Note: The way of describing the data changes if we use just "sum" intead of function "sum()"".
train.isnull().sum()
# Out:
# User_ID                    0
# Product_ID                 0
# Gender                     0
# Age                        0
# Occupation                 0
# City                       0
# Marital_Status             0
# Product_Category_1         0
# Product_Category_2    173637
# Product_Category_3    383246
# Purchase                   0
# dtype: int64

# %% [markdown]
# Clearly we can see the attributes with null values. But in real life scenarios, usually the dataset is very large and contains a high number of attributes. So to ease our analysis, we simply get the attributes with null values by using below code.

# %%
[features for features in train.columns if train[features].isnull().sum()>0]
# Out:
# ['Product_Category_2', 'Product_Category_3']

# %% [markdown]
# So, Product_Category_2, Product_Category_3 and Purchase attributes have null values and that too in very large numbers.

# %%
# Plotting a heatmap from seaborn library to get an idea of the null value frequency.
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# number of data entries which are not null.
train.count()
# Out:
# User_ID               550068
# Product_ID            550068
# Gender                550068
# Age                   550068
# Occupation            550068
# City                  550068
# Marital_Status        550068
# Product_Category_1    550068
# Product_Category_2    376431
# Product_Category_3    166822
# Purchase              550068
# dtype: int64

# %%
# To determine the number of male and female customers.
train['Gender'].value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
# To determine the noumber of married customers.
train['Marital_Status'].value_counts()
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
# To determine the no. of male and female customers.
train['Occupation'].value_counts()
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %%
# To determine the no. of male and female customers.
train['City'].value_counts()
# Out:
# B    231173
# C    171175
# A    147720
# Name: City, dtype: int64

# %%
# Another helpful function to find the number of unique values each attribute has. For example, Gender has two unique 
# value which are M and F.
train.nunique()
# Out:
# User_ID                5891
# Product_ID             3631
# Gender                    2
# Age                       7
# Occupation               21
# City                      3
# Marital_Status            2
# Product_Category_1       20
# Product_Category_2       17
# Product_Category_3       15
# Purchase              18105
# dtype: int64

# %%
train.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 550063    False
# 550064    False
# 550065    False
# 550066    False
# 550067    False
# Length: 550068, dtype: bool

# %%
train[train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender, Age, Occupation, City, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3, Purchase]
# Index: []

# %% [markdown]
# So the dataset has no duplicate rows. In case there were one or more duplicate rows, we will drop them immediately as they are of no use.

# %% [markdown]
# Whenever we come across null values in our data, we need to either drop the rows, drop the columns (when almost all entries are null), fill the data using several methods, etc.

# %% [markdown]
# The process of handling missing data really depends on the situation and importance of the project. For example if we need the attributes for research based project, then we prefer to drop the rows and/or columns to get the highest accuracy and precision. But for this case, we need an idea of data and insights so we can add data using state of the art methods.

# %% [markdown]
# Before dealing with the missing data, we need to understand the attributes of the dataset. So, after a close look, we can clearly see that the purchasing amount is more when there are non null values in all three attributes for product category. So this implies that the customer is buying one product and the purchasing value lies in a range. For thwo products the range changes and so on. So this method would bring the most accuracy and prcision in our analysis without droping the table. So this could have been a suitable option in case we had non null values in purchase column.

# %% [markdown]
# Lets fill the data using range and random.
# I personally prefer to fill the data without using min, max or mean. Instead, I find the range of the attribute and fill with random values or linear values within that range. This technique ensures diversity in data without compromising it's integrity.

# %% [markdown]
# So from here we would preprocess the data and make it suitable for mining, visualization and to be used in a machine learning model. For this puspose, will will be processing two datasets simultaneously i.e. the train and test datasets. Although we can combine them, pre process it and then split again into train and test data, we would respect the data provided for the sake of the problem.

# %%
train["Product_Category_2"] = train["Product_Category_2"].interpolate("linear")
train["Product_Category_3"] = train["Product_Category_3"].interpolate("linear")
train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City  Marital_Status  \
# 0       1000001  P00069042      F   0-17          10    A               0
# 1       1000001  P00248942      F   0-17          10    A               0
# 2       1000001  P00087842      F   0-17          10    A               0
# 3       1000001  P00085442      F   0-17          10    A               0
# 4       1000002  P00285442      M    55+          16    C               0
# ...         ...        ...    ...    ...         ...  ...             ...
# 550063  1006033  P00372445      M  51-55          13    B               1
# 550064  1006035  P00375436      F  26-35           1    C               0
# 550065  1006036  P00375436      F  26-35          15    B               1
# 550066  1006038  P00375436      F    55+           1    C               0
# 550067  1006039  P00371644      F  46-50           0    B               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# ...

# %%
train.isnull().sum()
# Out:
# User_ID               0
# Product_ID            0
# Gender                0
# Age                   0
# Occupation            0
# City                  0
# Marital_Status        0
# Product_Category_1    0
# Product_Category_2    0
# Product_Category_3    0
# Purchase              0
# dtype: int64

# %% [markdown]
# We have filled the missing values using interpolation.

# %% [markdown]
# There are two motives of modifiying the data. One is to make ist user frientdy and the other is to make it model friendly. User friendly data is important to make sure that it is understandable to the clients, stakeholders and data scientists in the company. Model friendly data needs to be mostly numeric and mathematical.

# %%
train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City  Marital_Status  \
# 0       1000001  P00069042      F   0-17          10    A               0
# 1       1000001  P00248942      F   0-17          10    A               0
# 2       1000001  P00087842      F   0-17          10    A               0
# 3       1000001  P00085442      F   0-17          10    A               0
# 4       1000002  P00285442      M    55+          16    C               0
# ...         ...        ...    ...    ...         ...  ...             ...
# 550063  1006033  P00372445      M  51-55          13    B               1
# 550064  1006035  P00375436      F  26-35           1    C               0
# 550065  1006036  P00375436      F  26-35          15    B               1
# 550066  1006038  P00375436      F    55+           1    C               0
# 550067  1006039  P00371644      F  46-50           0    B               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# ...

# %% [markdown]
# For projects purpose, we will modify it to be model friendly.

# %%
train['Gender'] = pd.factorize(train.Gender)[0]

# %%
train
# Out:
#         User_ID Product_ID  Gender    Age  Occupation City  Marital_Status  \
# 0       1000001  P00069042       0   0-17          10    A               0
# 1       1000001  P00248942       0   0-17          10    A               0
# 2       1000001  P00087842       0   0-17          10    A               0
# 3       1000001  P00085442       0   0-17          10    A               0
# 4       1000002  P00285442       1    55+          16    C               0
# ...         ...        ...     ...    ...         ...  ...             ...
# 550063  1006033  P00372445       1  51-55          13    B               1
# 550064  1006035  P00375436       0  26-35           1    C               0
# 550065  1006036  P00375436       0  26-35          15    B               1
# 550066  1006038  P00375436       0    55+           1    C               0
# 550067  1006039  P00371644       0  46-50           0    B               1
#
# ...

# %%
train['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
#  train['Age'] = pd.factorize(train.Age)[0]

# %% [markdown]
# Age Generalization <br>
# 0-17  - 0 <br>
# 18-25 - 1 <br>
# 26-35 - 2 <br>
# 36-45 - 3 <br>
# 46-50 - 4  <br>
# 51-55 - 5 <br>
# 55+   - 6 <br>

# %%
train = train.replace(to_replace = "0-17", value=0)
train = train.replace(to_replace = "18-25", value=1)
train = train.replace(to_replace = "26-35", value=2)
train = train.replace(to_replace = "36-45", value=3)
train = train.replace(to_replace = "46-50", value=4)
train = train.replace(to_replace = "51-55", value=5)
train = train.replace(to_replace = "55+", value=6)
train
# Out:
#         User_ID Product_ID  Gender  Age  Occupation City  Marital_Status  \
# 0       1000001  P00069042       0    0          10    A               0
# 1       1000001  P00248942       0    0          10    A               0
# 2       1000001  P00087842       0    0          10    A               0
# 3       1000001  P00085442       0    0          10    A               0
# 4       1000002  P00285442       1    6          16    C               0
# ...         ...        ...     ...  ...         ...  ...             ...
# 550063  1006033  P00372445       1    5          13    B               1
# 550064  1006035  P00375436       0    2           1    C               0
# 550065  1006036  P00375436       0    2          15    B               1
# 550066  1006038  P00375436       0    6           1    C               0
# 550067  1006039  P00371644       0    4           0    B               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# ...

# %%
# Checking for outliers using a scatter plot from matplotlib
matplotlib.rcParams["figure.figsize"] = (12, 6)
plt.style.use("bmh")
plt.scatter(train.Purchase.values, train.Product_Category_1.values)
plt.xlabel("Purchase")
plt.ylabel("Product Category 1")
# Out:
# Text(0, 0.5, 'Product Category 1')

# %%
matplotlib.rcParams["figure.figsize"] = (12, 6)
plt.style.use("bmh")
plt.scatter(train.Purchase.values, train.Product_Category_2.values)
plt.xlabel("Purchase")
plt.ylabel("Product Category 2")
# Out:
# Text(0, 0.5, 'Product Category 2')

# %%
matplotlib.rcParams["figure.figsize"] = (12, 6)
plt.style.use("bmh")
plt.scatter(train.Purchase.values, train.Product_Category_3.values)
plt.xlabel("Purchase")
plt.ylabel("Product Category 3")
# Out:
# Text(0, 0.5, 'Product Category 3')

# %% [markdown]
# ### Gender vs Purchase

# %%
# Intead of bar graphs, I prefer the use of linear graphs due to better visibility.
keys = [pair for pair, df in train.groupby(['Gender'])]
plt.plot(keys, train.groupby(['Gender']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
sns.countplot(x=train.Gender,data=train.Purchase,palette=['blue','red'])
# Out:
# <AxesSubplot:xlabel='Purchase', ylabel='count'>

# %%
# Pie chart for Gender only.
plt.pie(train.Gender.value_counts().values[:20], labels = train.Gender.value_counts().index[:20],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22449116580>,
# ...
#  [Text(-0.785367774085001, 0.7701931312526561, '1'),
#   Text(0.7853677019743126, -0.7701932047840901, '0')],
#  [Text(-0.42838242222818235, 0.42010534431963054, '75.31%'),
#   Text(0.42838238289507957, -0.42010538442768547, '24.69%')])

# %% [markdown]
# Here, 0 is for female and 1 is for male. So from these plots and graphs we can say that the number of customers are mostly males. The percentage of males and females are 75.31 and 24.69 respectively meaning that the ratio is approximately 3:1.

# %% [markdown]
# ### Age vs Purchase

# %%
keys = [pair for pair, df in train.groupby(['Age'])]
plt.plot(keys, train.groupby(['Age']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
# Pie chart for Age only.
plt.pie(train.Age.value_counts().values[:20], labels = train.Age.value_counts().index[:20],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2244d1a0bb0>,
# ...
#  [Text(0.34254781550769436, 1.0453042590991901, '2'),
#   Text(-1.0999860751865844, 0.005534834741354073, '3'),
#   Text(-0.406302589631829, -1.0222124073099825, '1'),
#   Text(0.48031423239356413, -0.9895949869316141, '4'),
#   Text(0.8836014705420766, -0.655170543641791, '5'),
#   Text(1.0523803112495336, -0.32014946586607823, '6'),
#   Text(1.0959108835259952, -0.09475935504884372, '0')],
#  [Text(0.1868442630041969, 0.5701659595086491, '39.92%'),
#   Text(-0.5999924046472278, 0.0030190007680113125, '20.00%'),
#   Text(-0.221619594344634, -0.5575704039872632, '18.12%'),
#   Text(0.2619895813055804, -0.5397790837808804, '8.31%'),
#   Text(0.48196443847749626, -0.3573657510773405, '7.00%'),
#   Text(0.5740256243179273, -0.17462698138149718, '3.91%'),
#   Text(0.597769572832361, -0.05168692093573293, '2.75%')])

# %% [markdown]
# The age group labelled 2, which is 26 to 35 years old are purchasing most number of products. And the youngest and the oldest aged individuals buy the least products. The dominant customer population consists of 39.92 percent of the total customers. The other group of customers in the range 18-25 and 36-45 also share a customer population of 18.12% and 20.00%, which is also considerably large. The rest share the remaining 20%(approx).

# %% [markdown]
# ### Occupation vs Purchase

# %%
keys = [pair for pair, df in train.groupby(['Occupation'])]
plt.plot(keys, train.groupby(['Occupation']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
# Pie chart for Occupation only.
plt.pie(train.Occupation.value_counts().values[:20], labels = train.Occupation.value_counts().index[:20],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2244d4ef2b0>,
# ...
#  [Text(1.0070111187838093, 0.44263823450508744, '4'),
#   Text(0.37065248581770804, 1.035672117398723, '0'),
#   Text(-0.4221082629182033, 1.0157876817407154, '7'),
#   Text(-0.92807125781708, 0.5904944880469447, '1'),
#   Text(-1.0976276986105666, 0.07220412206288165, '17'),
#   Text(-1.0310756895581208, -0.383253078790303, '20'),
#   Text(-0.8221282436506984, -0.730824979726212, '12'),
#   Text(-0.5361701341683774, -0.9604798734100909, '14'),
#   Text(-0.21902411945260977, -1.0779742274739268, '2'),
#   Text(0.10668195122001387, -1.0948145784944092, '16'),
#   Text(0.3864991107218648, -1.0298633100616839, '6'),
#   Text(0.5997823904562636, -0.9220960275907116, '3'),
#   Text(0.7512811278457417, -0.8034778571577629, '10'),
#   Text(0.8586672947190609, -0.6875248918983585, '5'),
#   Text(0.9458775878724637, -0.5615296864463802, '15'),
#   Text(1.0132896722915976, -0.4280701344723629, '11'),
# ...

# %% [markdown]
# The top five occupations to which the large crowd in customers belong is occupation 4, 0, 7, 1 and 17. So there is a 50 percent chance that the customer buys something if they belong to these occupations.

# %% [markdown]
# ### City vs Purchase

# %%
keys = [pair for pair, df in train.groupby(['City'])]
plt.plot(keys, train.groupby(['City']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
# Pie chart for City only.
plt.pie(train.City.value_counts().values[:20], labels = train.City.value_counts().index[:20],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x224529fb100>,
# ...
#  [Text(0.27267989579948126, 1.0656667745720443, 'B'),
#   Text(-0.9774040218269879, -0.5046596656326213, 'C'),
#   Text(0.7311976184733743, -0.8217968378734892, 'A')],
#  [Text(0.14873448861789884, 0.5812727861302059, '42.03%'),
#   Text(-0.5331294664510843, -0.27526890852688435, '31.12%'),
#   Text(0.3988350646218405, -0.4482528206582668, '26.85%')])

# %% [markdown]
# Customer are mostly from city B. this might imply that city B is near to the shop or the shop has high reputation nand trust in city B. City A and city C are also attracting customers in good numbers. HAving three cities populate the data can indicate that the shop is present in city B and city A and city C are the neighbouring cities.

# %% [markdown]
# ### Marital_Status vs Purchase

# %%
keys = [pair for pair, df in train.groupby(['Marital_Status'])]
plt.plot(keys, train.groupby(['Marital_Status']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %% [markdown]
# ### Product_Category_1 vs Purchase

# %%
keys = [pair for pair, df in train.groupby(['Product_Category_1'])]
plt.plot(keys, train.groupby(['Product_Category_1']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
# Pie chart for Product_Category_1 only.
plt.pie(train.Product_Category_1.value_counts().values[:20], labels = train.Product_Category_1.value_counts().index[:20],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22452d33340>,
# ...
#  [Text(0.7159952330593233, 0.8350753416526712, '5'),
#   Text(-0.897934430599324, 0.6353847325394814, '1'),
#   Text(-0.7370040328598891, -0.8165935681526396, '8'),
#   Text(0.06063841555599795, -1.0983273567378982, '11'),
#   Text(0.35661139538427433, -1.040590367379057, '2'),
#   Text(0.605894965855439, -0.9180911122274502, '6'),
#   Text(0.8010018928307994, -0.7539203987699741, '3'),
#   Text(0.9245674682849536, -0.5959656001726539, '4'),
#   Text(0.9908233972636981, -0.4777750468942726, '16'),
#   Text(1.0305474484438566, -0.3846712317107386, '15'),
#   Text(1.054182622392725, -0.3141639677703304, '13'),
#   Text(1.071364620775545, -0.24935486630597928, '10'),
#   Text(1.0828408495951083, -0.19353473705809018, '12'),
#   Text(1.0902755831416036, -0.14594229272296746, '7'),
#   Text(1.0951471077472266, -0.10321246239134498, '18'),
#   Text(1.097916615311446, -0.06766909060316025, '20'),
# ...

# %%
sns.distplot(train["Product_Category_1"])
# Out:
# E:\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Product_Category_1', ylabel='Density'>

# %%
sns.relplot(x = "Product_Category_1", y = "Purchase", data = train)

# %% [markdown]
# Let's assume that these numbers indicate a particular product from product category 1. For example, 5 indicates iron from category "ELECTRONICS". Now using this chronology </br>
# - We can safely say that product 5, 1 and 8 are in extremely high demand.</br>
# - Males are the dominant buyers of his category of products. </br>
# -

# %% [markdown]
# ### Product_Category_2 vs Purchase

# %%
# For City and Purchase
keys = [pair for pair, df in train.groupby(['Product_Category_2'])]
plt.plot(keys, train.groupby(['Product_Category_2']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
sns.distplot(train["Product_Category_2"])
# Out:
# E:\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Product_Category_2', ylabel='Density'>

# %%
sns.relplot(x = "Product_Category_2", y = "Purchase", data = train)

# %% [markdown]
# ### Product_Category_3 vs Purchase

# %%
# For City and Purchase
keys = [pair for pair, df in train.groupby(['Product_Category_3'])]
plt.plot(keys, train.groupby(['Product_Category_3']).count()['Purchase'])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
sns.distplot(train["Product_Category_3"])
# Out:
# E:\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Product_Category_3', ylabel='Density'>

# %%
sns.relplot(x = "Product_Category_3", y = "Purchase", data = train)

# %% [markdown]
# Other useful plots and graphs are implemented below.

# %%
corr = train.corr()
sns.heatmap(corr, annot = True, cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Predictive Model

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder
train['outlet'] = le.fit_transform(df['Outlier_Identifier'])
cat_col = ['']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = train.drop(columns=["User_ID","City", "Product_ID", "Purchase"])
y = train['Purchase']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 2)

# %%
regr = LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = regr.predict(x_test)

# %%
pred
# Out:
# array([11334.50846802,  9085.6416276 ,  6689.51506034, ...,
#         8213.42813939, 11463.6498609 ,  7574.59567   ])

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
def train(model, X, y):
    # train the model
    model.fit(X, y)
    
    # predict the training set
    pred = model.predict(X)
    
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
    
    print("Model Report")
    print("MSE:",mean_squared_error(y,pred))
    print("CV Score:", cv_score)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# ...

# %%
model = Ridge(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# ...

# %%
model = Lasso()
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# Model Report
# MSE: 22094256.056099046
# CV Score: 22134188.87393491
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# Model Report
# MSE: 4068250.2798344134
# CV Score: 13626419.22280858
# <AxesSubplot:title={'center':'Feature Importance'}>
